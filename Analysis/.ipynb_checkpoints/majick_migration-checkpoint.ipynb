# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime as dt
import time
from scipy.misc import imread

# %%
# ------------------------------------ Cleanup CSV files --------------------------------------------------------

# Get sources of raw data for cleanup
species_filename1 = "../Data/Clean/Monarch/Monarch_clean.csv"
species_filename2 = "../Data/Clean/Whale/Blue_Whale.csv"
species_filename3 = "../Data/Clean/Whale/Humpback_whale.csv"
species_filename4 = "../Data/Clean/Tern/Arctic Tern.csv"

# Reading csv files
df_monarch = pd.read_csv(species_filename1)
#df_blue_whale = pd.read_csv(species_filename2)
#df_humpback_whale = pd.read_csv(species_filename3)
#df_arctic_tern = pd.read_csv(species_filename4)

# %%
df_blue_whale.head()
# Out:
#      event-id                timestamp  location-long  location-lat  \
# 0  8393723602  1994-09-15 01:53:29.000       -123.288        37.554
# 1  8393723603  1994-09-15 03:22:44.000       -122.581        37.440
# 2  8393723604  1994-09-15 04:06:31.000       -123.611        37.693
# 3  8393723605  1994-09-15 12:35:24.000       -122.977        37.880
# 4  8393723606  1994-09-15 16:21:18.000       -123.162        37.760
#
#   individual-taxon-canonical-name tag-local-identifier  \
# 0           Balaenoptera musculus    1994CA-ST10-10823
# 1           Balaenoptera musculus    1994CA-ST10-10823
# 2           Balaenoptera musculus    1994CA-ST10-10823
# 3           Balaenoptera musculus    1994CA-ST10-10823
# 4           Balaenoptera musculus    1994CA-ST10-10823
#
#   individual-local-identifier
# 0            1994CA-Bmu-10823
# 1            1994CA-Bmu-10823
# 2            1994CA-Bmu-10823
# 3            1994CA-Bmu-10823
# 4            1994CA-Bmu-10823

# %%
df_humpback_whale.head()
# Out:
#                                                 geom      oid  longitude  \
# 0  0103000020E61000000100000005000000000000000060...  5823119       -180
# 1  0103000020E61000000100000005000000000000000060...   180494       -180
# 2  0103000020E61000000100000005000000000000000060...   180338       -180
# 3  0103000020E61000000100000005000000000000000040...   180589       -178
# 4  0103000020E61000000100000005000000000000000020...  5823772       -177
#
#    latitude                          providers                 species  \
# 0       -17      Wildlife Conservation Society  Megaptera novaeangliae
# 1        61  National Marine Mammal Laboratory  Megaptera novaeangliae
# 2        62  National Marine Mammal Laboratory  Megaptera novaeangliae
# 3        60  National Marine Mammal Laboratory  Megaptera novaeangliae
# 4       -23      Wildlife Conservation Society  Megaptera novaeangliae
#
#   datasets   date_min   date_max  num_records  num_animals   csquare  \
# 0      885   8/1/1913   8/1/1913            1          1.0  5117:479
# 1      821  7/18/2008  7/18/2008            2          2.0  7617:209
# 2      821  7/31/2010  7/31/2010            1          3.0  7617:229
# 3      821  7/29/2010  7/30/2010            5          6.0  7517:498
# 4      885  10/1/1913  10/1/1913            3          3.0  5217:237
#
#                                             geom_wkt
# 0  POLYGON((-179 -17,-179 -18,-180 -18,-180 -17,-...
# 1  POLYGON((-179 60,-180 60,-180 61,-179 61,-179 ...
# 2  POLYGON((-179 62,-180 62,-180 63,-179 63,-179 ...
# 3  POLYGON((-178 59,-179 59,-179 60,-178 60,-178 ...
# 4  POLYGON((-177 -23,-177 -24,-178 -24,-178 -23,-...

# %%
df_monarch.head(20)
# Out:
#          id observed_on_string observed_on quality_grade   license   latitude  \
# 0    621484    4/12/2014 16:09   4/12/2014      research  CC-BY-NC  35.511898
# 1    768989          6/29/2014   6/29/2014      research  CC-BY-NC  35.513389
# 2    837014          8/17/2014   8/17/2014      research  CC-BY-NC  35.507590
# 3    866569           9/7/2014    9/7/2014      research  CC-BY-NC  35.512094
# 4    875141          9/13/2014   9/13/2014      research  CC-BY-NC  35.513659
# 5   1037595         10/25/2014  10/25/2014      research  CC-BY-NC  35.513604
# 6   1928642           9/7/2015    9/7/2015      research  CC-BY-NC  35.508247
# 7   1942210    9/12/2015 17:06   9/12/2015      research  CC-BY-NC  35.509889
# 8   1965231    9/19/2015 17:22   9/19/2015      research  CC-BY-NC  35.508889
# 9   1965232    9/19/2015 17:27   9/19/2015      research  CC-BY-NC  35.509564
# 10  2004018    9/26/2015 16:20   9/26/2015      research  CC-BY-NC  35.511343
# 11  2005091    9/26/2015 16:04   9/26/2015      research  CC-BY-NC  35.509531
# 12  2074300    10/3/2015 15:09   10/3/2015      research  CC-BY-NC  35.504933
# 13  2091530    10/9/2015 16:20   10/9/2015      research  CC-BY-NC  35.513079
# 14  3444414    6/12/2016 11:04   6/12/2016      research  CC-BY-NC  35.509435
# 15  3984151    8/28/2016 18:10   8/28/2016      research  CC-BY-NC  35.509435
# 16  4026995     9/3/2016 10:54    9/3/2016      research  CC-BY-NC  35.509688
# 17  4026996     9/3/2016 10:42    9/3/2016      research  CC-BY-NC  35.508063
# 18  4026997      9/3/2016 7:50    9/3/2016      research  CC-BY-NC  35.508063
# 19  5629493     4/9/2017 11:34    4/9/2017      research  CC-BY-NC  35.506884
#
#     longitude  positional_accuracy   scientific_name common_name
# 0  -93.323380                 27.0  Danaus plexippus     Monarch
# 1  -93.326598                  3.0  Danaus plexippus     Monarch
# 2  -93.315497                 13.0  Danaus plexippus     Monarch
# 3  -93.326470                 27.0  Danaus plexippus     Monarch
# 4  -93.318597                  3.0  Danaus plexippus     Monarch
# 5  -93.317261                  6.0  Danaus plexippus     Monarch
# 6  -93.320848                 27.0  Danaus plexippus     Monarch
# 7  -93.323635                 13.0  Danaus plexippus     Monarch
# 8  -93.316635                 13.0  Danaus plexippus     Monarch
# 9  -93.316623                  6.0  Danaus plexippus     Monarch
# 10 -93.316539                  6.0  Danaus plexippus     Monarch
# 11 -93.316621                 27.0  Danaus plexippus     Monarch
# 12 -93.313173                  6.0  Danaus plexippus     Monarch
# 13 -93.322583                  3.0  Danaus plexippus     Monarch
# 14 -93.323535                  NaN  Danaus plexippus     Monarch
# 15 -93.321572                  NaN  Danaus plexippus     Monarch
# 16 -93.322463                  NaN  Danaus plexippus     Monarch
# 17 -93.320875                  NaN  Danaus plexippus     Monarch
# 18 -93.320875                  NaN  Danaus plexippus     Monarch
# 19 -93.316433                  NaN  Danaus plexippus     Monarch

# %%
df_monarch.count()
# Out:
# id                     578
# observed_on_string     576
# observed_on            572
# quality_grade          578
# license                546
# latitude               565
# longitude              565
# positional_accuracy    449
# scientific_name        578
# common_name            578
# dtype: int64

# %%
df_arctic_tern.head()
# Out:
#      row_id  latitude  longitude         scientific       common series_id  \
# 0  705_3443     13.46     -60.41  Sterna paradisaea  Arctic Tern  ARTE_410
# 1  705_3187    -19.51     -36.14  Sterna paradisaea  Arctic Tern  ARTE_410
# 2  705_3177     -9.54     -18.05  Sterna paradisaea  Arctic Tern  ARTE_410
# 3  705_3158     44.61     -32.36  Sterna paradisaea  Arctic Tern  ARTE_410
# 4  705_3154     46.15     -32.94  Sterna paradisaea  Arctic Tern  ARTE_410
#
#          date_time                                             oceano
# 0  5/13/2008 15:58  "CHL_D":0.1600,"CHL_M":0.1600,"CHL_Y":0.1400,"...
# 1  10/13/2007 2:11  "CHL_D":-9999,"CHL_M":0.0800,"CHL_Y":0.0600,"S...
# 2   10/8/2007 1:00  "CHL_D":-9999,"CHL_M":-9999,"CHL_Y":0.0600,"SS...
# 3   9/12/2007 2:06  "CHL_D":0.1200,"CHL_M":0.1300,"CHL_Y":0.2500,"...
# 4   9/10/2007 2:09  "CHL_D":0.1900,"CHL_M":0.2000,"CHL_Y":0.3200,"...

# %%
monarch_adj = df_monarch.dropna(subset = ['latitude','longitude','observed_on'])
monarch_adj['year'] = pd.DatetimeIndex(monarch_adj['observed_on']).year
monarch_adj['month']= pd.DatetimeIndex(monarch_adj['observed_on']).month
monarch_2014 = monarch_adj.loc[monarch_adj['year'] == 2014]
monarch_2015 = monarch_adj.loc[monarch_adj['year'] == 2015]
monarch_2016 = monarch_adj.loc[monarch_adj['year'] == 2016]
monarch_2017 = monarch_adj.loc[monarch_adj['year'] == 2017]
monarch_2018 = monarch_adj.loc[monarch_adj['year'] == 2018]

monarch_2014.count()
# Out:
# C:\Users\Event Horizon\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Event Horizon\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# id                     6
# observed_on_string     6
# observed_on            6
# quality_grade          6
# license                6
# latitude               6
# longitude              6
# positional_accuracy    6
# scientific_name        6
# common_name            6
# year                   6
# month                  6
# dtype: int64

# %%
stderr_lon_2017=monarch_2017.longitude.sem(axis=0)
stderr_lat_2017=monarch_2017.latitude.sem(axis=0)
stderr_lon_2018=monarch_2017.longitude.sem(axis=0)
stderr_lon_2018=monarch_2017.latitude.sem(axis=0)

# %%
plt.scatter(monarch_2014.month,monarch_2014.latitude,s=300,alpha = 0.75,color = 'purple',edgecolor = 'black',linewidth=0.75)
plt.scatter(monarch_2015.month,monarch_2015.latitude,s=300,alpha = 0.75,color = 'green',edgecolor = 'black',linewidth=0.75)
plt.scatter(monarch_2016.month,monarch_2016.latitude,s=200,alpha = 0.75,color = 'yellow',edgecolor = 'black',linewidth=0.75)
plt.scatter(monarch_2017.month,monarch_2017.latitude,s=150, alpha = 0.5,color = 'blue',edgecolor = 'black',linewidth=0.75)
plt.scatter(monarch_2018.month,monarch_2018.latitude,s=50 ,alpha = 0.4,color = 'red',edgecolor = 'black',linewidth=0.75)

plt.show()

# %%
plt.scatter(monarch_2017.longitude,monarch_2017.month,s=150, alpha = 0.5,color = 'blue',edgecolor = 'black',linewidth=0.75)
plt.scatter(monarch_2018.longitude,monarch_2018.month,s=50 ,alpha = 0.4,color = 'red',edgecolor = 'black',linewidth=0.75)

# %%
plt.scatter(monarch_2017.latitude,monarch_2017.longitude,s=50, alpha = 0.5,color = 'blue',edgecolor = 'black',linewidth=0.75)
plt.scatter(monarch_2018.latitude,monarch_2018.longitude,s=50 ,alpha = 0.4,color = 'red',edgecolor = 'black',linewidth=0.75)
plt.scatter(monarch_2018.latitude,monarch_2018.longitude,s=50 ,alpha = 0.4,color = 'red',edgecolor = 'black',linewidth=0.75)

# %%
ind = np.arange(monarch_adj.month)    # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence
lon1 = plt.bar(ind, monarch_2017.longitude, width, yerr=stderr_lon_2017)
lon2 = plt.bar(ind, monarch_2018.longitude, width,
             bottom=monarch_2018.longitude, yerr=stderr_lon_2018)

plt.ylabel('Count')
plt.xticks(ind, ('4', '5', '6', '7', '8', '9', '10', '11', '12'))
plt.yticks(np.arange(0, 200, 10))

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-110-30f1e479b4fc> in <module>()
# ----> 1 ind = np.arange(monarch_adj.month)    # the x locations for the groups
#       2 width = 0.35       # the width of the bars: can also be len(x) sequence
#       3 lon1 = plt.bar(ind, monarch_2017.longitude, width, yerr=stderr_lon_2017)
#       4 lon2 = plt.bar(ind, monarch_2018.longitude, width,
#       5              bottom=monarch_2018.longitude, yerr=stderr_lon_2018)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1574         raise ValueError("The truth value of a {0} is ambiguous. "
#    1575                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1576                          .format(self.__class__.__name__))
#    1577
#    1578     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
